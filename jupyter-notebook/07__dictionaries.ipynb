# %%
# recall lists 
lst = [ 1, 2, 3, 4 ]

# %%
d = {
    "package": "A package is a module that can be added to any program",
    "random": "Any data or information that has no order",
    "unary operator": "An operator that takes only one value for its operation"
}

# %%
d['package']
# Out:
# 'A package is a module that can be added to any program'

# %%
d['random']
# Out:
# 'Any data or information that has no order'

# %%
d['variable'] = "A memory location, the value of which can change"

# %%
d
# Out:
# {'package': 'A package is a module that can be added to any program',
#  'random': 'Any data or information that has no order',
#  'unary operator': 'An operator that takes only one value for its operation',
#  'variable': 'A memory location, the value of which can change'}

# %%
d['python']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d['python']
#
# KeyError: 'python'

# %%
for a in d:
    print(a)
# Out:
# package
# random
# unary operator
# variable

# %%
for k in d:
    v = d[k]
    print (k, "=", v)
# Out:
# package = A package is a module that can be added to any program
# random = Any data or information that has no order
# unary operator = An operator that takes only one value for its operation
# variable = A memory location, the value of which can change

# %%
'package' in d
# Out:
# True

# %%
'random' in d
# Out:
# True

# %%
'python' in d
# Out:
# False

# %%
'else' in d
# Out:
# False

# %%
if 'else' not in d:   # you can move the 'not'
    print("The keyword 'else' is not in d... how can this be?")
else:
    print("this keyword was found.")
# Out:
# The keyword 'else' is not in d... how can this be?

# %%
if not 'else' in d:   # you can move the 'not'
    print("The keyword 'else' is not in d... how can this be?")
else:
    print("this keyword was found.")
# Out:
# The keyword 'else' is not in d... how can this be?

# %%
list(d.items())          # returns a list of tuples!
# Out:
# [('package', 'A package is a module that can be added to any program'),
#  ('random', 'Any data or information that has no order'),
#  ('unary operator', 'An operator that takes only one value for its operation'),
#  ('variable', 'A memory location, the value of which can change')]

# %%
l = list(d.items())          # returns a list of tuples!

# %%
type(l[0])
# Out:
# tuple

# %%
type(l[0][0])
# Out:
# str

# %%
for k, v in d.items():
    print(k, "=", v)
# Out:
# package = A package is a module that can be added to any program
# random = Any data or information that has no order
# unary operator = An operator that takes only one value for its operation
# variable = A memory location, the value of which can change

# %%
autograder_conf = {
    'url' : '121.52.146.108:8000',
    'username' : 'p1111111',
    'submission pass' : 'abc-334'
}

print('Connecting to', autograder_conf['url'])
# Out:
# Connecting to 121.52.146.108:8000

# %%
autograder_conf = {
    'url' : '121.52.146.108:8000',
    'username' : 'p1111111',
    'submission pass' : 'abc-334'
}

print('Connecting to', autograder_conf['username'])
# Out:
# Connecting to p1111111

# %%
num_names = {
    1: "one",
    2: "two",
    3: "three"
}

# %%
num_names[3]
# Out:
# 'three'

# %%
num_names = {
    1: "one",
    2: "two",
    3: "three",
    20: "twenty",
    30: "thirty",
    1000: "thousand"
}

# %%
num_names[3000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 num_names[3000]
#
# KeyError: 3000

# %%
v = "1"
num_names["1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 2
#       1 v = "1"
# ----> 2 num_names["1"]
#
# KeyError: '1'

# %%
v = "1"
num_names[1]
# Out:
# 'one'

# %%
v = "1"
num_names[ v ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 2
#       1 v = "1"
# ----> 2 num_names[ v ]
#
# KeyError: '1'

# %%
v = 1
num_names[ v ]
# Out:
# 'one'

# %%
v = "1"
num_names[v]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 2
#       1 v = "1"
# ----> 2 num_names[v]
#
# KeyError: '1'

# %%
num_names[ int(v) ]
# Out:
# 'one'
