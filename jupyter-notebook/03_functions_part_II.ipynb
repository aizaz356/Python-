# %%
def f(x):                     # name x used as formal parameter
    y = 1                     # local variable
    x = x + y
    print ('x =' , x)
    print ('p =' , p)         # global variable
    return x

# %%
p = 20
x = 3
y = 2
z = f(x)                      # value of x used as actual parameter

print('z ='  , z)
print('x ='  , x)
print('y ='  , y)
# Out:
# x = 4
# p = 20
# z = 4
# x = 3
# y = 2

# %%
y = 25

def f(x):                    # name x used as formal parameter
    print ('y =', y)
    x = 25 + 9
    
    
    
    
x = 2
f(x)
# Out:
# y = 25

# %%
y = 25

def f(x):
    print ('y =', y)
    x = 25 + 9
    
    y = 1       # variables are global unless assigned to inside the function
    
    
x = 2
f(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 11
#       7     y = 1       # variables are global unless assigned to inside the function
#      10 x = 2
# ---> 11 f(x)
#
# Cell In[9], line 4, in f(x)
#       3 def f(x):
# ----> 4     print ('y =', y)
#       5     x = 25 + 9
#       7     y = 1
#
# UnboundLocalError: cannot access local variable 'y' where it is not associated with a value

# %%
y = 25

def f(x):
    y = 1       # variables are global unless assigned to inside the function
    print ('y =', y)
    x = 25 + 9
    
    
x = 2
f(x)
# Out:
# y = 1

# %%
def pressure(v, t, n):
    """Compute the pressure in pascals of an ideal gas.
    
    Applies the ideal gas law.
    
    v -- volume of gas, in cubic meters
    t -- absolute temperature in degrees kelvin
    n -- particles of gas
    """
    k = 1.38e-23   # Boltzmann's constant
    return n * k * t / v

# %%
help(pressure)
# Out:
# Help on function pressure in module __main__:
#
# pressure(v, t, n)
#     Compute the pressure in pascals of an ideal gas.
#
#     Applies the ideal gas law.
#
#     v -- volume of gas, in cubic meters
#     t -- absolute temperature in degrees kelvin
#     n -- particles of gas
