# %%
def square(x):
    return x * x      # notice the indentation (also, this is a comment)

# %%
square(5)
# Out:
# 25

# %%
v = square(5)

# %%
v
# Out:
# 25

# %%
type(v)
# Out:
# int

# %%
def square(x):
    print (x * x)

# %%
square(5)
# Out:
# 25

# %%
v = square(5)
# Out:
# 25

# %%
v

# %%
type(v)
# Out:
# NoneType

# %%
def square(x):
    return x * x

# %%
def sum_squares(x, y):
    return square(x) + square(y)

# %%
result = sum_squares(3, 4)

# %%
result
# Out:
# 25

# %%
def square(x):
    return x * x

# %%
def sum_squares(x, y):
    a = square(x)
    b = square(y)
    return a + b

# %%
result = sum_squares(3, 4)

# %%
result
# Out:
# 25

# %%
def square(x):
    return x * x

# %%
def sum_squares(x,y):
    return square(x) + square(y)

# %%
result = sum_squares('a', 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 result = sum_squares('a', 3)
#
# Cell In[27], line 2, in sum_squares(x, y)
#       1 def sum_squares(x,y):
# ----> 2     return square(x) + square(y)
#
# Cell In[26], line 2, in square(x)
#       1 def square(x):
# ----> 2     return x * x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
def sqrt(num, guess):
    print ("Finding square root of", num , "starting with guess:" , guess)

# %%
sqrt(36, 1)     # but we don't need to specify the 1
# Out:
# Finding square root of 36 starting with guess: 1

# %%
sqrt(36)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sqrt(36)
#
# TypeError: sqrt() missing 1 required positional argument: 'guess'

# %%
def sqrt(num, guess=1):
    print ("Finding square root of", num , "starting with guess:" , guess)

# %%
sqrt(36, 1)
# Out:
# Finding square root of 36 starting with guess: 1

# %%
sqrt(36)
# Out:
# Finding square root of 36 starting with guess: 1

# %%
def sqrt(num, guess=1):
    print ("Finding square root of", num , "starting with guess:" , guess)

# %%
sqrt(36,5.5)
# Out:
# Finding square root of 36 starting with guess: 5.5

# %%
sqrt(36)
# Out:
# Finding square root of 36 starting with guess: 1

# %%
sqrt(5.5)
# Out:
# Finding square root of 5.5 starting with guess: 1
